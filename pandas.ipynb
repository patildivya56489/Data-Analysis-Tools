# %% [markdown]
# ### Pandas
#
# > Pandas is a powerfull python library for manipulation and alanaysis of data
#
# > Its a open source library
#
# >fast(built on top of numpy),flexible(different resource), productive library

# %% [markdown]
# Instal

# %% [markdown]
# Install

# %%
! pip install pandas
# Out:
# Access is denied.

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# ###Series - One dimentional array(data structure)with label

# %% [markdown]
# Series - One dimensional array(data structure)with label

# %% [markdown]
# l1 = [1,2,3,4,5]
# type(1)

# %%
l1 = [1,2,3,4,5]
type(l1)
# Out:
# list

# %%
pd.Series(l1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series(l1,name = "Series")
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Series, dtype: int64

# %%
s= pd.Series(l1,index = ["a","b","c","d","e"],name = "My Series")

# %%
s['a']
# Out:
# np.int64(1)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Note: Index in Series are immutable(can change)

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
### changing the index of pandas series

s = s.rename(index = {'b':'y'})

# %%
s
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: My Series, dtype: int64

# %%
s.rename(index = {'b':'y'},inplace = True)

# %% [markdown]
# # Dataframe - its a 2d array(just like tables)

# %%
dict1 = {'name':['virat','rohit','dhoni','jadeja','bumrah'],
'age':[34,33,40,32,30],
'marks':[80,85,75,80,70],
'Role':['batsman','batsman','wicketkeeper','allrounder','bowler']}



pd.DataFrame(dict1)
# Out:
#      name  age  marks          Role
# 0   virat   34     80       batsman
# 1   rohit   33     85       batsman
# 2   dhoni   40     75  wicketkeeper
# 3  jadeja   32     80    allrounder
# 4  bumrah   30     70        bowler

# %%
df = pd.DataFrame(dict1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail(2)
# Out:
#      name  age  marks        Role
# 3  jadeja   32     80  allrounder
# 4  bumrah   30     70      bowler

# %%
df.head(2)
# Out:
#     name  age  marks     Role
# 0  virat   34     80  batsman
# 1  rohit   33     85  batsman

# %%
len(df)
# Out:
# 5

# %%
df.count()
# Out:
# name     5
# age      5
# marks    5
# Role     5
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks', 'Role'], dtype='object')

# %%
df['name']
# Out:
# 0     virat
# 1     rohit
# 2     dhoni
# 3    jadeja
# 4    bumrah
# Name: name, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df['name'].value_counts()
# Out:
# name
# virat     1
# rohit     1
# dhoni     1
# jadeja    1
# bumrah    1
# Name: count, dtype: int64

# %% [markdown]
# ### Basic operations
#
# > Importing data set from different files
#
# > Importing tabular dataset

# %%
pd.read_csv(r"C:\Users\klemp\Desktop\Divya Anu\datasets\ETH_1h.csv")
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df = pd.read_csv(r"C:\Users\klemp\Desktop\Divya Anu\datasets\ETH_1h.csv")

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %% [markdown]
# # top 5 rows

# %%
stock_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
stock_df.head(10)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 5  2020-03-13 03-PM  ETHUSD  128.39  128.90  116.06  124.85  7378976.00
# 6  2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 7  2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 8  2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# 9  2020-03-13 11-AM  ETHUSD  132.60  133.17  126.01  128.93  3311080.29

# %% [markdown]
# > bottom 5 rows

# %%
stock_df.tail()
# Out:
#                    Date  Symbol    Open    High    Low   Close      Volume
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.0  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.0  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.1  275.01   679358.87

# %%
## Number of rows in dataframe
len(stock_df)
# Out:
# 23674

# %% [markdown]
#  ## Access column names of dataframe

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
## accessing a column in a dataframe
stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
stock_df[['Date','Open','Low']]
# Out:
#                    Date    Open     Low
# 0      2020-03-13 08-PM  129.94  126.87
# 1      2020-03-13 07-PM  119.51  117.10
# 2      2020-03-13 06-PM  124.47  115.50
# 3      2020-03-13 05-PM  124.08  121.63
# 4      2020-03-13 04-PM  124.85  120.17
# ...                 ...     ...     ...
# 23669  2017-07-01 03-PM  265.74  265.00
# 23670  2017-07-01 02-PM  268.79  265.00
# 23671  2017-07-01 01-PM  274.83  265.00
# 23672  2017-07-01 12-PM  275.01  271.00
# 23673  2017-07-01 11-AM  279.98  272.10
#
# [23674 rows x 3 columns]

# %% [markdown]
# ## Accessing rows and dataframe

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
[1,2,3,4,'hello',True]
# Out:
# [1, 2, 3, 4, 'hello', True]

# %% [markdown]
# ## Accessing rows

# %%
stock_df.loc[23672]
# Out:
# Date      2017-07-01 12-PM
# Symbol              ETHUSD
# Open                275.01
# High                275.01
# Low                  271.0
# Close               274.83
# Volume           824362.87
# Name: 23672, dtype: object

# %%
stock_df.loc[23672,'Date']
# Out:
# '2017-07-01 12-PM'

# %%
stock_df.loc[23672,['Date','Close','Open']]
# Out:
# Date     2017-07-01 12-PM
# Close              274.83
# Open               275.01
# Name: 23672, dtype: object

# %%
stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
l = [1,2,3,4,5]
l[1:4] # slicing a list
# Out:
# [2, 3, 4]

# %%
d2 = [[1,2,3],
      [4,5,6],
      [7,8,9]]
d2
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
d2[2][1]
# Out:
# 8

# %%
d2
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# #### Slicing in loc (labeled location)
#
# df.loc['row_label_1':'row_label_3':'column_label_1':'column_label_2']

# %%
stock_df.loc[23672,'Open':'Close']
# Out:
# Open     275.01
# High     275.01
# Low       271.0
# Close    274.83
# Name: 23672, dtype: object

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.iloc[1]
# Out:
# Date      2020-03-13 07-PM
# Symbol              ETHUSD
# Open                119.51
# High                132.02
# Low                  117.1
# Close               129.94
# Volume          7579741.09
# Name: 1, dtype: object

# %%
stock_df .iloc[1,2] # row index and column index
# Out:
# np.float64(119.51)

# %%
stock_df .iloc[3,[2,4]] # multuple column index
# Out:
# Open    124.08
# Low     121.63
# Name: 3, dtype: object

# %%
stock_df .iloc[2,5:6] # slicing of colmns using iloc
# Out:
# Close    119.51
# Name: 2, dtype: object

# %%
stock_df .iloc[1:6,2:6]
# Out:
#      Open    High     Low   Close
# 1  119.51  132.02  117.10  129.94
# 2  124.47  124.85  115.50  119.51
# 3  124.08  127.42  121.63  124.47
# 4  124.85  129.51  120.17  124.08
# 5  128.39  128.90  116.06  124.85

# %% [markdown]
# ## Filtering

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df['High']
# Out:
# 0        131.82
# 1        132.02
# 2        124.85
# 3        127.42
# 4        129.51
#           ...
# 23669    272.74
# 23670    269.90
# 23671    274.93
# 23672    275.01
# 23673    279.99
# Name: High, Length: 23674, dtype: float64

# %%
stock_df['High'] > 130
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 23669     True
# 23670     True
# 23671     True
# 23672     True
# 23673     True
# Name: High, Length: 23674, dtype: bool

# %%
f1 = stock_df['High'] > 130


stock_df[f1]
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 6      2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 7      2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 8      2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [21613 rows x 7 columns]

# %%
f1 = stock_df['High'] > 130


stock_gt_130 = stock_df[f1]

# %%
stock_gt_130.reset_index(drop=True,inplace=True)

# %%
stock_gt_130
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 3      2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 4      2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# ...                 ...     ...     ...     ...     ...     ...         ...
# 21608  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 21609  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 21610  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 21611  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 21612  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [21613 rows x 7 columns]

# %% [markdown]
# Adding new column

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
len(stock_df)
# Out:
# 23674

# %%
stock_df['Random_col'] = list(range(1,len(stock_df)+1))

# %%
stock_df['Random_col']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 23669    23670
# 23670    23671
# 23671    23672
# 23672    23673
# 23673    23674
# Name: Random_col, Length: 23674, dtype: int64

# %% [markdown]
# Dropping column

# %%
stock_df.drop(columns = ['Random_col'],inplace = True)

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.drop(columns=['Open','High'],inplace=True)

# %%
stock_df
# Out:
#                    Date  Symbol     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  272.10  275.01   679358.87
#
# [23674 rows x 5 columns]

# %%
stock_df.iloc[len(stock_df)-1]
# Out:
# Date      2017-07-01 11-AM
# Symbol              ETHUSD
# Low                  272.1
# Close               275.01
# Volume           679358.87
# Name: 23673, dtype: object

# %% [markdown]
# Dropping rows
